# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# This notebook performs exploratory data analysis on GPS signals for spoofing detection.

# %%
import sys
sys.path.append('..')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src.preprocessing import load_signal, normalize_signal
from src.utils import plot_signal, plot_spectrum

# %matplotlib inline
sns.set_style('whitegrid')

# %% [markdown]
# ## 1. Load Data
#
# Load GPS signal data from the data directory.

# %%
# Example: Load a signal file
# signal, metadata = load_signal('../data/your_signal.mat')
# print(f"Signal shape: {signal.shape}")
# print(f"Metadata: {metadata}")

# %% [markdown]
# ## 2. Visualize Signals
#
# Plot time-domain and frequency-domain representations.

# %%
# Example: Visualize signal
# fs = 5e6  # Sampling frequency
# plot_signal(signal[:10000], fs, title='Raw GPS Signal')
# plot_spectrum(signal[:10000], fs, title='Signal Spectrum')

# %% [markdown]
# ## 3. Signal Statistics
#
# Compute basic statistics of the signal.

# %%
# Example: Compute statistics
# print(f"Mean: {np.mean(np.abs(signal))}")
# print(f"Std: {np.std(np.abs(signal))}")
# print(f"Power: {np.mean(np.abs(signal)**2)}")

# %% [markdown]
# ## 4. Class Distribution
#
# Analyze the distribution of authentic vs. spoofed signals.

# %%
# Example: Load labels and visualize distribution
# labels = ...
# plt.figure(figsize=(8, 5))
# pd.Series(labels).value_counts().plot(kind='bar')
# plt.title('Class Distribution')
# plt.xlabel('Class (0=Authentic, 1=Spoofed)')
# plt.ylabel('Count')
# plt.show()
